# %%
# !pip install Twython
import pandas as pd
import numpy as np
from twython import Twython
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Twython in /usr/local/lib/python3.7/dist-packages (3.9.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from Twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from Twython) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.4.0->Twython) (3.2.0)
# Mounted at /content/gdrive

# %%
CONSUMER_KEY = "Uv3Ccd0oSCf9LgawJx12EAqYl"
CONSUMER_SECRET = "NdsEcNJvTIhBVD8ApxthiidqxuY8MdKzmzPyb1tLdWCSDvLhW4"
OAUTH_TOKEN = "469275739-tpD9kkY4CCl2r8IZ2CimxNuF9DiEGtdb0fKwWLBK"
OAUTH_TOKEN_SECRET = "3Fx1ECS8mv4feMg6vfHsnFTGE5ExV845QHLPIgHuZOKF4"

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %%
tweets = []
MAX_ATTEMPTS = 40
COUNT_OF_TWEETS_TO_BE_FETCHED = 10000

for i in range(0, MAX_ATTEMPTS):
  
  if(COUNT_OF_TWEETS_TO_BE_FETCHED < len(tweets)):
    print(len(tweets), " tweets found.")

  if(i==0):
    results = twitter.search(q='ξαφνικιτιδα', count='1000')
    print(len(results['statuses']), " tweets found.")
  
  else:
    results = twitter.search(q="ξαφνικιτιδα",count='1000', include_entities='true',max_id=next_max_id)
    print("I Got:", len(results['statuses']), " tweets")

  for result in results['statuses']:
    tweets.append(result)

  try:
    next_results_url_params = results['search_metadata']['next_results']
    next_max_id = next_results_url_params.split('max_id=')[1].split('&')[0]
  except:
    break
# Out:
# 100  tweets found.
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 100  tweets
# I Got: 80  tweets
# I Got: 0  tweets

# %%
tweets_df = pd.DataFrame(tweets)
tweets_df
# Out:
#                           created_at                   id  \
# 0     Wed Jun 29 17:43:21 +0000 2022  1542202071788683265
# 1     Wed Jun 29 17:37:16 +0000 2022  1542200542386159616
# 2     Wed Jun 29 17:12:08 +0000 2022  1542194216192843778
# 3     Wed Jun 29 17:11:20 +0000 2022  1542194015021457413
# 4     Wed Jun 29 16:58:46 +0000 2022  1542190854344949762
# ...                              ...                  ...
# 2875  Mon Jun 20 11:26:18 +0000 2022  1538845694114648067
# 2876  Mon Jun 20 11:25:44 +0000 2022  1538845553114730501
# 2877  Mon Jun 20 11:23:43 +0000 2022  1538845042231623681
# 2878  Mon Jun 20 11:19:45 +0000 2022  1538844045111439360
# 2879  Mon Jun 20 11:18:18 +0000 2022  1538843682291560449
#
#                    id_str                                               text  \
# 0     1542202071788683265  RT @PanagiotisMylo6: Προσωπικές εμπειρίες..!!\...
# 1     1542200542386159616  RT @dstefanos: Τον πήραν στο ψιλό τον #Πλεύρη ...
# 2     1542194216192843778  RT @PanagiotisMylo6: Προσωπικές εμπειρίες..!!\...
# 3     1542194015021457413  RT @PanagiotisMylo6: Προσωπικές εμπειρίες..!!\...
# 4     1542190854344949762  RT @dstefanos: Τον πήραν στο ψιλό τον #Πλεύρη ...
# ...                   ...                                                ...
# 2875  1538845694114648067  RT @Kalhas821: Η Παγώνη μόλις δήλωσε στον #σκα...
# 2876  1538845553114730501  Η Παγώνη μόλις δήλωσε στον #σκαι_ξεφτιλες Ότι ...
# 2877  1538845042231623681  Μετά από 2μιση χρόνια κορωνοιου δεν υπάρχει κα...
# 2878  1538844045111439360  RT @panos__pao: Όταν η επιστήμη έχει φτάσει σε...
# 2879  1538843682291560449  Κοίτα ρε φίλε που αυτοί που δεν βλέπουν #ξαφνι...
#
#       truncated                                           entities  \
# 0         False  {'hashtags': [{'text': 'ξαφνικοθανατιτιδα', 'i...
# 1         False  {'hashtags': [{'text': 'Πλεύρη', 'indices': [3...
# 2         False  {'hashtags': [{'text': 'ξαφνικοθανατιτιδα', 'i...
# 3         False  {'hashtags': [{'text': 'ξαφνικοθανατιτιδα', 'i...
# 4         False  {'hashtags': [{'text': 'Πλεύρη', 'indices': [3...
# ...         ...                                                ...
# 2875      False  {'hashtags': [{'text': 'σκαι_ξεφτιλες', 'indic...
# 2876       True  {'hashtags': [{'text': 'σκαι_ξεφτιλες', 'indic...
# 2877       True  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2878      False  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2879      False  {'hashtags': [{'text': 'ξαφνικιτιδα', 'indices...
#
#                                       extended_entities  \
# 0     {'media': [{'id': 1542163940481925122, 'id_str...
# 1                                                   NaN
# 2     {'media': [{'id': 1542163940481925122, 'id_str...
# 3     {'media': [{'id': 1542163940481925122, 'id_str...
# 4                                                   NaN
# ...                                                 ...
# 2875                                                NaN
# 2876                                                NaN
# 2877                                                NaN
# 2878                                                NaN
# 2879                                                NaN
#
#                                                metadata  \
# 0     {'iso_language_code': 'el', 'result_type': 're...
# 1     {'iso_language_code': 'el', 'result_type': 're...
# 2     {'iso_language_code': 'el', 'result_type': 're...
# 3     {'iso_language_code': 'el', 'result_type': 're...
# 4     {'iso_language_code': 'el', 'result_type': 're...
# ...                                                 ...
# 2875  {'iso_language_code': 'el', 'result_type': 're...
# 2876  {'iso_language_code': 'el', 'result_type': 're...
# 2877  {'iso_language_code': 'el', 'result_type': 're...
# 2878  {'iso_language_code': 'el', 'result_type': 're...
# 2879  {'iso_language_code': 'el', 'result_type': 're...
#
#                                                  source  \
# 0     <a href="https://mobile.twitter.com" rel="nofo...
# 1     <a href="http://twitter.com/download/android" ...
# 2     <a href="http://twitter.com/download/android" ...
# 3     <a href="https://mobile.twitter.com" rel="nofo...
# 4     <a href="http://twitter.com/download/android" ...
# ...                                                 ...
# 2875  <a href="https://mobile.twitter.com" rel="nofo...
# 2876  <a href="http://twitter.com/download/android" ...
# 2877  <a href="http://twitter.com/download/android" ...
# 2878  <a href="http://twitter.com/download/android" ...
# 2879  <a href="http://twitter.com/download/android" ...
#
#       in_reply_to_status_id  ... is_quote_status  retweet_count  \
# 0                       NaN  ...           False              7
# 1                       NaN  ...           False             72
# 2                       NaN  ...           False              7
# 3                       NaN  ...           False              7
# 4                       NaN  ...           False             72
# ...                     ...  ...             ...            ...
# 2875                    NaN  ...           False             73
# 2876                    NaN  ...           False             73
# 2877                    NaN  ...           False              0
# 2878                    NaN  ...           False             13
# 2879                    NaN  ...           False              0
#
#      favorite_count favorited retweeted possibly_sensitive lang  \
# 0                 0     False     False              False   el
# 1                 0     False     False                NaN   el
# 2                 0     False     False              False   el
# 3                 0     False     False              False   el
# 4                 0     False     False                NaN   el
# ...             ...       ...       ...                ...  ...
# 2875              0     False     False                NaN   el
# 2876            369     False     False                NaN   el
# 2877              0     False     False              False   el
# 2878              0     False     False                NaN   el
# 2879              2     False     False                NaN   el
#
#      quoted_status_id quoted_status_id_str quoted_status
# 0                 NaN                  NaN           NaN
# 1                 NaN                  NaN           NaN
# 2                 NaN                  NaN           NaN
# 3                 NaN                  NaN           NaN
# 4                 NaN                  NaN           NaN
# ...               ...                  ...           ...
# 2875              NaN                  NaN           NaN
# 2876              NaN                  NaN           NaN
# 2877              NaN                  NaN           NaN
# 2878              NaN                  NaN           NaN
# 2879              NaN                  NaN           NaN
#
# [2880 rows x 30 columns]

# %%
tweets_df.to_csv("/content/gdrive/My Drive/Colab Notebooks/xafnikitida_tweets.tsv", sep='\t')
